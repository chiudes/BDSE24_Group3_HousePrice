# %%
import pandas as pd

# %%
df = pd.read_xml('GDP.xml')

# %%
df
# Out:
#                               Item  TIME_PERIOD FREQ TYPE  Item_VALUE
# 0          A.農、林、漁、牧業#生產總額(新台幣百萬元)         1981    A  原始值    269102.0
# 1          A.農、林、漁、牧業#中間消費(新台幣百萬元)         1981    A  原始值    136413.0
# 2        A.農、林、漁、牧業#國內生產毛額(新台幣百萬元)         1981    A  原始值    132689.0
# 3      A.農、林、漁、牧業#生產及進口稅淨額(新台幣百萬元)         1981    A  原始值      1481.0
# 4        A.農、林、漁、牧業#固定資本消耗(新台幣百萬元)         1981    A  原始值      5600.0
# ...                            ...          ...  ...  ...         ...
# 23515    補充項目:ICT產業#國內生產毛額(新台幣百萬元)         2020    A  原始值   3734859.0
# 23516  補充項目:ICT產業#生產及進口稅淨額(新台幣百萬元)         2020    A  原始值     17877.0
# 23517    補充項目:ICT產業#固定資本消耗(新台幣百萬元)         2020    A  原始值   1241116.0
# 23518    補充項目:ICT產業#受僱人員報酬(新台幣百萬元)         2020    A  原始值   1213254.0
# 23519      補充項目:ICT產業#營業盈餘(新台幣百萬元)         2020    A  原始值   1262612.0
#
# [23520 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23520 entries, 0 to 23519
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Item         23520 non-null  object
#  1   TIME_PERIOD  23520 non-null  int64
#  2   FREQ         23520 non-null  object
#  3   TYPE         23520 non-null  object
#  4   Item_VALUE   23345 non-null  float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 918.9+ KB

# %%
df1 = df[df['TIME_PERIOD'] == 1981]

# %%
df1
# Out:
#                             Item  TIME_PERIOD FREQ TYPE  Item_VALUE
# 0        A.農、林、漁、牧業#生產總額(新台幣百萬元)         1981    A  原始值    269102.0
# 1        A.農、林、漁、牧業#中間消費(新台幣百萬元)         1981    A  原始值    136413.0
# 2      A.農、林、漁、牧業#國內生產毛額(新台幣百萬元)         1981    A  原始值    132689.0
# 3    A.農、林、漁、牧業#生產及進口稅淨額(新台幣百萬元)         1981    A  原始值      1481.0
# 4      A.農、林、漁、牧業#固定資本消耗(新台幣百萬元)         1981    A  原始值      5600.0
# ..                           ...          ...  ...  ...         ...
# 583    補充項目:ICT產業#國內生產毛額(新台幣百萬元)         1981    A  原始值     77176.0
# 584  補充項目:ICT產業#生產及進口稅淨額(新台幣百萬元)         1981    A  原始值      7340.0
# 585    補充項目:ICT產業#固定資本消耗(新台幣百萬元)         1981    A  原始值     16896.0
# 586    補充項目:ICT產業#受僱人員報酬(新台幣百萬元)         1981    A  原始值     32781.0
# 587      補充項目:ICT產業#營業盈餘(新台幣百萬元)         1981    A  原始值     20159.0
#
# [588 rows x 5 columns]

# %%
df1['Item'].unique()
# Out:
# array(['A.農、林、漁、牧業#生產總額(新台幣百萬元)', 'A.農、林、漁、牧業#中間消費(新台幣百萬元)',
#        'A.農、林、漁、牧業#國內生產毛額(新台幣百萬元)', 'A.農、林、漁、牧業#生產及進口稅淨額(新台幣百萬元)',
#        'A.農、林、漁、牧業#固定資本消耗(新台幣百萬元)', 'A.農、林、漁、牧業#受僱人員報酬(新台幣百萬元)',
#        'A.農、林、漁、牧業#營業盈餘(新台幣百萬元)', 'AA.農耕業#生產總額(新台幣百萬元)',
#        'AA.農耕業#中間消費(新台幣百萬元)', 'AA.農耕業#國內生產毛額(新台幣百萬元)',
#        'AA.農耕業#生產及進口稅淨額(新台幣百萬元)', 'AA.農耕業#固定資本消耗(新台幣百萬元)',
#        'AA.農耕業#受僱人員報酬(新台幣百萬元)', 'AA.農耕業#營業盈餘(新台幣百萬元)',
#        'AB.畜牧業#生產總額(新台幣百萬元)', 'AB.畜牧業#中間消費(新台幣百萬元)',
#        'AB.畜牧業#國內生產毛額(新台幣百萬元)', 'AB.畜牧業#生產及進口稅淨額(新台幣百萬元)',
#        'AB.畜牧業#固定資本消耗(新台幣百萬元)', 'AB.畜牧業#受僱人員報酬(新台幣百萬元)',
#        'AB.畜牧業#營業盈餘(新台幣百萬元)', 'AC.林業#生產總額(新台幣百萬元)', 'AC.林業#中間消費(新台幣百萬元)',
#        'AC.林業#國內生產毛額(新台幣百萬元)', 'AC.林業#生產及進口稅淨額(新台幣百萬元)',
#        'AC.林業#固定資本消耗(新台幣百萬元)', 'AC.林業#受僱人員報酬(新台幣百萬元)',
#        'AC.林業#營業盈餘(新台幣百萬元)', 'AD.漁業#生產總額(新台幣百萬元)', 'AD.漁業#中間消費(新台幣百萬元)',
#        'AD.漁業#國內生產毛額(新台幣百萬元)', 'AD.漁業#生產及進口稅淨額(新台幣百萬元)',
#        'AD.漁業#固定資本消耗(新台幣百萬元)', 'AD.漁業#受僱人員報酬(新台幣百萬元)',
# ...

# %%
df2 = df[df['Item'] == '總計(生產面)#國內生產毛額(新台幣百萬元)']

# %%
df2
# Out:
#                          Item  TIME_PERIOD FREQ TYPE  Item_VALUE
# 555    總計(生產面)#國內生產毛額(新台幣百萬元)         1981    A  原始值   1804431.0
# 1143   總計(生產面)#國內生產毛額(新台幣百萬元)         1982    A  原始值   1945351.0
# 1731   總計(生產面)#國內生產毛額(新台幣百萬元)         1983    A  原始值   2162286.0
# 2319   總計(生產面)#國內生產毛額(新台幣百萬元)         1984    A  原始值   2411382.0
# 2907   總計(生產面)#國內生產毛額(新台幣百萬元)         1985    A  原始值   2532587.0
# 3495   總計(生產面)#國內生產毛額(新台幣百萬元)         1986    A  原始值   2965448.0
# 4083   總計(生產面)#國內生產毛額(新台幣百萬元)         1987    A  原始值   3325211.0
# 4671   總計(生產面)#國內生產毛額(新台幣百萬元)         1988    A  原始值   3611241.0
# 5259   總計(生產面)#國內生產毛額(新台幣百萬元)         1989    A  原始值   4060413.0
# 5847   總計(生產面)#國內生產毛額(新台幣百萬元)         1990    A  原始值   4482881.0
# 6435   總計(生產面)#國內生產毛額(新台幣百萬元)         1991    A  原始值   5018019.0
# 7023   總計(生產面)#國內生產毛額(新台幣百萬元)         1992    A  原始值   5575157.0
# 7611   總計(生產面)#國內生產毛額(新台幣百萬元)         1993    A  原始值   6197349.0
# ...

# %%
# 篩選出 2012~2021 年
df2 = df2[ df2['TIME_PERIOD'] >= 2012 ]
df2 = df2[ df2['TIME_PERIOD'] <= 2022 ]

# %%
df2
# Out:
#                          Item  TIME_PERIOD FREQ TYPE  Item_VALUE
# 18783  總計(生產面)#國內生產毛額(新台幣百萬元)         2012    A  原始值  14546008.0
# 19371  總計(生產面)#國內生產毛額(新台幣百萬元)         2013    A  原始值  15263797.0
# 19959  總計(生產面)#國內生產毛額(新台幣百萬元)         2014    A  原始值  16343457.0
# 20547  總計(生產面)#國內生產毛額(新台幣百萬元)         2015    A  原始值  17022620.0
# 21135  總計(生產面)#國內生產毛額(新台幣百萬元)         2016    A  原始值  17555268.0
# 21723  總計(生產面)#國內生產毛額(新台幣百萬元)         2017    A  原始值  18054749.0
# 22311  總計(生產面)#國內生產毛額(新台幣百萬元)         2018    A  原始值  18451874.0
# 22899  總計(生產面)#國內生產毛額(新台幣百萬元)         2019    A  原始值  18882644.0
# 23487  總計(生產面)#國內生產毛額(新台幣百萬元)         2020    A  原始值  19713643.0

# %%
## 缺資料，此資料最後更新時間是2021
