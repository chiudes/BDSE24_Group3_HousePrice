# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("落後指標構成項目.csv", header=[0])
#pd.set_option("display.max_columns", None)

# %%
df
# Out:
#        Date  失業率(%)  製造業單位產出勞動成本指數(2011=100)  金融業隔夜拆款利率(年息百分比)  \
# 0    198201    1.36                   121.65            12.890
# 1    198202    1.62                    96.58            14.830
# 2    198203    1.32                    84.16            11.720
# 3    198204    1.49                    87.20            11.870
# 4    198205    1.98                    86.56            11.990
# ..      ...     ...                      ...               ...
# 478  202111    3.66                    79.21             0.082
# 479  202112    3.64                    81.39             0.083
# 480  202201    3.61                   159.72             0.085
# 481  202202    3.65                    91.41             0.081
# 482  202203    3.66                    72.72             0.122
#
#     全體金融機構放款與投資(10億元)  製造業存貨價值(千元)
# 0                   -    159946328
# 1                   -    165470731
# 2                   -    163420163
# 3                   -    161756961
# ...

# %%
df.iloc[:,2]
# Out:
# 0      121.65
# 1       96.58
# 2       84.16
# 3       87.20
# 4       86.56
#         ...
# 478     79.21
# 479     81.39
# 480    159.72
# 481     91.41
# 482     72.72
# Name: 製造業單位產出勞動成本指數(2011=100), Length: 483, dtype: float64

# %%
hp_drop.rename(columns={
"a": "地址" ,   
"b": "建物型態", 
"bs": "主建物占比(%)",
"twn": "縣市+行政區",
"cp": "車位總價",
"e": "交易日期",
"f": "樓層",
"g": "屋齡",
"j": "土地(筆)",
"l": "車位(個)",
"lat": "緯度",
"lon": "經度",
"m": "管理組織",
"pu": "使用用途",
"s": "移轉總面積",
"tp": "交易總價",
"v": "總格局"
}, inplace = True)
# Out:
# C:\Users\Student\anaconda3\lib\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
#hp_drop

# %%
#hp_drop['房']=hp_drop['總格局'].str.split('房').str.get(0)
#hp_drop

# %%
#hp_drop['房']=hp_drop['總格局'].str[:1]
#hp_drop['廳']=hp_drop['總格局'].str[2:3]
#hp_drop['衛']=hp_drop['總格局'].str[4:5]

# %%
codes, uniques = pd.factorize(hp_drop['總格局'])
for i in uniques:
    print(i)
# Out:
# 1房1廳1衛
# 3房2廳1衛
# 3房2廳2衛
# 3房0廳0衛
# 4房0廳0衛
# 1房0廳1衛
# 2房1廳1衛
# 2房2廳1衛
# 2房2廳2衛
# 2房3廳2衛
# 1房2廳2衛
# 4房2廳4衛
# 1房0廳0衛
# 6房3廳3衛
# 2房1廳2衛
# 1房2廳1衛
# 0房1廳1衛
# 4房2廳3衛
# 3房2廳3衛
# 3房1廳1衛
# 4房2廳2衛
# 6房6廳6衛
# 4房4廳2衛
# 6房0廳3衛
# 4房0廳4衛
# 4房0廳1衛
# 6房0廳6衛
# 5房1廳2衛
# 4房1廳1衛
# 3房3廳3衛
# 4房1廳2衛
# 3房2廳4衛
# 0房2廳2衛
# 3房1廳0衛
# 0房0廳1衛
# 5房1廳4衛
# 3房1廳2衛
# 2房2廳3衛
# 2房0廳2衛
# 19房0廳19衛
# 0房1廳0衛
# 4房1廳3衛
# 6房1廳1衛
# 5房2廳2衛
# 1房1廳2衛
# 5房4廳6衛
# 5房3廳3衛
# 5房5廳5衛
# 4房0廳2衛
# 7房2廳3衛
# 4房1廳4衛
# 0房2廳0衛
# 7房2廳5衛
# 2房2廳8衛
# 1房1廳0衛
# 2房4廳2衛
# 5房1廳5衛
# 0房3廳1衛
# 9房2廳5衛
# 0房2廳1衛
# 9房1廳2衛
# 8房0廳8衛
# 4房2廳5衛
# 6房0廳0衛
# 15房0廳0衛
# 4房4廳4衛
# 8房2廳0衛
# 2房0廳1衛
# 7房3廳3衛
# 5房2廳3衛
# 7房1廳4衛
# 3房0廳3衛
# 5房0廳5衛
# 14房1廳0衛
# 3房0廳1衛
# 2房1廳0衛
# 12房1廳8衛
# 4房3廳3衛
# 8房6廳6衛
# 11房0廳11衛
# 40房0廳40衛
# 6房3廳6衛
# 6房1廳6衛
# 0房2廳3衛
# 1房0廳3衛
# 7房0廳7衛
# 4房1廳0衛
# 11房1廳7衛
# 0房3廳3衛
# 16房1廳3衛
# 5房3廳2衛
# 3房1廳3衛
# 0房0廳3衛
# 7房0廳0衛
# 6房4廳7衛
# 3房0廳2衛
# 1房0廳2衛
# 10房2廳2衛
# 6房2廳2衛
# 6房4廳5衛
# 1房1廳4衛
# 3房3廳2衛
# 7房1廳3衛
# 5房2廳1衛
# 1房3廳3衛
# 6房3廳2衛
# 1房2廳0衛
# 3房4廳2衛
# 8房0廳4衛
# ...

# %%
hp_drop['房']=hp_drop['總格局'].str.split('(\u623F|\u5EF3|\u885B)').str.get(0)
hp_drop['廳']=hp_drop['總格局'].str.split('(\u623F|\u5EF3|\u885B)').str.get(2)
hp_drop['衛']=hp_drop['總格局'].str.split('(\u623F|\u5EF3|\u885B)').str.get(4)
# Out:
# C:\Users\Student\AppData\Local\Temp/ipykernel_11688/1980111869.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hp_drop['房']=hp_drop['總格局'].str.split('(\u623F|\u5EF3|\u885B)').str.get(0)
# C:\Users\Student\AppData\Local\Temp/ipykernel_11688/1980111869.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hp_drop['廳']=hp_drop['總格局'].str.split('(\u623F|\u5EF3|\u885B)').str.get(2)
# C:\Users\Student\AppData\Local\Temp/ipykernel_11688/1980111869.py:3: SettingWithCopyWarning:
# ...

# %%
hp_drop
# Out:
#                                          地址             建物型態 主建物占比(%) 縣市+行政區  \
# 0             建國北路二段００３５號二樓之２#建國北路二段３５號二樓之２  住宅大樓(11層含以上有電梯)   63.81%    A10
# 1       新生北路二段０６８巷０００８號五樓之９#新生北路二段６８巷８號五樓之９  住宅大樓(11層含以上有電梯)   48.90%    A10
# 2                      龍江路０４５５號二樓#龍江路４５５號二樓     公寓(5樓含以下無電梯)   94.21%    A10
# 3             建國北路二段００３３號七樓之４#建國北路二段３３號七樓之４  住宅大樓(11層含以上有電梯)   83.30%    A10
# 4             建國北路二段００３３號七樓之３#建國北路二段３３號七樓之３  住宅大樓(11層含以上有電梯)   80.24%    A10
# ...                                     ...              ...      ...    ...
# 835890                   宏慶街０００２號４樓#宏慶街２號４樓     公寓(5樓含以下無電梯)   91.16%    H07
# 835891                  文光街００５３號四樓#文光街５３號四樓     公寓(5樓含以下無電梯)   88.61%    H07
# 835892                幸福九街００１０號四樓#幸福九街１０號四樓     公寓(5樓含以下無電梯)   85.00%    H07
# 835893                 明成街０２１２號五樓#明成街２１２號五樓    華廈(10層含以下有電梯)   53.69%    H07
# 835894               興華一街０３８６號五樓#興華一街３８６號五樓    華廈(10層含以下有電梯)   48.40%    H07
#
# ...

# %%
hp_drop['房'].unique()
# Out:
# array(['1', '3', '4', '2', nan, '6', '0', '5', '19', '7', '9', '8', '15',
#        '14', '12', '11', '40', '16', '10', '42', '35', '13', '24', '18',
#        '34', '17', '20', '30', '60', '26', '33', '25', '23', '168', '41',
#        '98', '49', '32', '27', '88', '21', '45', '68', '44', '50', '39',
#        '54', '80', '62', '22', '55', '140', '29', '31', '37', '90', '51',
#        '36', '59', '77', '28', '47', '46', '52', '215', '48', '38', '61',
#        '56', '43', '66', '120', '100', '110', '126'], dtype=object)

# %%
hp_drop['廳'].unique()
# Out:
# array(['1', '2', '0', '3', nan, '6', '4', '5', '8', '7', '16', '19', '9',
#        '11', '14', '22', '10', '20', '56', '80', '24', '21', '40', '25',
#        '12', '60', '17', '15', '18', '41', '13', '43', '30', '215', '26',
#        '32', '27', '33', '34', '66', '23', '29', '65', '49'], dtype=object)

# %%
y = hp_drop['衛'].index[hp_drop['衛'].astype(str)=="nan"]

# %%
hp_drop['衛'][y].shape
# Out:
# (51088,)

# %%
hp_drop_totalroom= hp_drop.drop(['總格局'], axis=1)
#hp_drop_totalroom

# %%
hp_drop_totalroom
# Out:
#                                          地址             建物型態 主建物占比(%) 縣市+行政區  \
# 0             建國北路二段００３５號二樓之２#建國北路二段３５號二樓之２  住宅大樓(11層含以上有電梯)   63.81%    A10
# 1       新生北路二段０６８巷０００８號五樓之９#新生北路二段６８巷８號五樓之９  住宅大樓(11層含以上有電梯)   48.90%    A10
# 2                      龍江路０４５５號二樓#龍江路４５５號二樓     公寓(5樓含以下無電梯)   94.21%    A10
# 3             建國北路二段００３３號七樓之４#建國北路二段３３號七樓之４  住宅大樓(11層含以上有電梯)   83.30%    A10
# 4             建國北路二段００３３號七樓之３#建國北路二段３３號七樓之３  住宅大樓(11層含以上有電梯)   80.24%    A10
# ...                                     ...              ...      ...    ...
# 835890                   宏慶街０００２號４樓#宏慶街２號４樓     公寓(5樓含以下無電梯)   91.16%    H07
# 835891                  文光街００５３號四樓#文光街５３號四樓     公寓(5樓含以下無電梯)   88.61%    H07
# 835892                幸福九街００１０號四樓#幸福九街１０號四樓     公寓(5樓含以下無電梯)   85.00%    H07
# 835893                 明成街０２１２號五樓#明成街２１２號五樓    華廈(10層含以下有電梯)   53.69%    H07
# 835894               興華一街０３８６號五樓#興華一街３８６號五樓    華廈(10層含以下有電梯)   48.40%    H07
#
# ...

# %%
#hp_drop
hp_drop_totalroom.to_csv("0.5_addcolname_dropcols.csv", index=False)
